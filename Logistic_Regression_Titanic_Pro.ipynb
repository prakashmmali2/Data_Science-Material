# %%
# Collecting Data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import math

titanic_data = pd.read_csv('https://github.com/datasciencedojo/datasets/raw/master/titanic.csv')

print(titanic_data.head(10))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
print("No of Passenger in Original Data : ", str(len(titanic_data.index)))
# Out:
# No of Passenger in Original Data :  891

# %%
# Analysis Data

sns.countplot(x = 'Survived' , data = titanic_data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# Analysis Data

sns.countplot(x = "Survived" , hue = "Sex" , data = titanic_data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# Analysis Data

sns.countplot(x = 'Survived' , hue = 'Pclass' , data = titanic_data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
titanic_data['Age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
titanic_data['Fare'].plot.hist(bins = 20 , figsize = (10,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_data['Parch'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.countplot(x = 'SibSp' , data = titanic_data)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
#titanic_data['Ticket'].plot.hist()
sns.countplot(x = 'Ticket' , data = titanic_data)
# Out:
# <Axes: xlabel='Ticket', ylabel='count'>

# %%
## Data Wrangling

titanic_data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(titanic_data.isnull() , yticklabels = False)
# Out:
# <Axes: >

# %%
sns.boxplot(x = 'Pclass' , y = 'Age' , data = titanic_data)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
titanic_data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_data.drop("Cabin" , axis = 1, inplace = True)

# %%
titanic_data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
titanic_data.dropna(inplace = True)

sns.heatmap(titanic_data.isnull(),yticklabels = False , cbar = False)
# Out:
# <Axes: >

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic_data.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
Sex =  pd.get_dummies(titanic_data['Sex'],drop_first = True)
Sex.head(5)
# Out:
#     male
# 0   True
# 1  False
# 2  False
# 3  False
# 4   True

# %%
embark =  pd.get_dummies(titanic_data['Embarked'],drop_first = True)

embark.head(5)
# Out:
#        Q      S
# 0  False   True
# 1  False  False
# 2  False   True
# 3  False   True
# 4  False   True

# %%
Pclas =  pd.get_dummies(titanic_data['Pclass'],drop_first = True)

Pclas.head(5)
# Out:
#        2      3
# 0  False   True
# 1  False  False
# 2  False   True
# 3  False  False
# 4  False   True

# %%
titanic_data = pd.concat([titanic_data,Sex,embark , Pclas],axis = 1)

titanic_data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked   male      Q      S      2  \
# 0      0         A/5 21171   7.2500        S   True  False   True  False
# 1      0          PC 17599  71.2833        C  False  False  False  False
# 2      0  STON/O2. 3101282   7.9250        S  False  False   True  False
# ...

# %%
titanic_data.drop(['Sex','Embarked','PassengerId','Name','Ticket'],axis = 1, inplace = True)
titanic_data.head(5)
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare   male      Q      S      2  \
# 0         0       3  22.0      1      0   7.2500   True  False   True  False
# 1         1       1  38.0      1      0  71.2833  False  False  False  False
# 2         1       3  26.0      0      0   7.9250  False  False   True  False
# 3         1       1  35.0      1      0  53.1000  False  False   True  False
# 4         0       3  35.0      0      0   8.0500   True  False   True  False
#
#        3
# 0   True
# 1  False
# 2   True
# 3  False
# 4   True

# %%
titanic_data.head(5)
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare   male      Q      S      2  \
# 0         0       3  22.0      1      0   7.2500   True  False   True  False
# 1         1       1  38.0      1      0  71.2833  False  False  False  False
# 2         1       3  26.0      0      0   7.9250  False  False   True  False
# 3         1       1  35.0      1      0  53.1000  False  False   True  False
# 4         0       3  35.0      0      0   8.0500   True  False   True  False
#
#        3
# 0   True
# 1  False
# 2   True
# 3  False
# 4   True

# %%
titanic_data.drop('Pclass', axis = 1 , inplace = True)

# %%
## Test and Train DataSet

x = titanic_data.drop('Survived', axis = 1)
y = titanic_data['Age']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)>

# %%
print(x_train)
# Out:
#       Age  SibSp  Parch     Fare   male      Q      S      2      3
# 58    5.0      1      2  27.7500  False  False   True   True  False
# 57   28.5      0      0   7.2292   True  False  False  False   True
# 96   71.0      0      0  34.6542   True  False  False  False  False
# 210  24.0      0      0   7.0500   True  False   True  False   True
# 569  32.0      0      0   7.8542   True  False   True  False   True
# ..    ...    ...    ...      ...    ...    ...    ...    ...    ...
# 93   26.0      1      2  20.5750   True  False   True  False   True
# 135  23.0      0      0  15.0458   True  False  False   True  False
# 338  45.0      0      0   8.0500   True  False   True  False   True
# 549   8.0      1      1  36.7500   True  False   True   True  False
# 131  20.0      0      0   7.0500   True  False   True  False   True
#
# [498 rows x 9 columns]

# %%
print(x_test)
# Out:
#       Age  SibSp  Parch      Fare   male      Q      S      2      3
# 641  24.0      0      0   69.3000  False  False  False  False  False
# 496  54.0      1      0   78.2667  False  False  False  False  False
# 262  52.0      1      1   79.6500   True  False   True  False  False
# 311  18.0      2      2  262.3750  False  False  False  False  False
# 551  27.0      0      0   26.0000   True  False   True   True  False
# ..    ...    ...    ...       ...    ...    ...    ...    ...    ...
# 818  43.0      0      0    6.4500   True  False   True  False   True
# 478  22.0      0      0    7.5208   True  False   True  False   True
# 325  36.0      0      0  135.6333  False  False  False  False  False
# 175  18.0      1      1    7.8542   True  False   True  False   True
# 37   21.0      0      0    8.0500   True  False   True  False   True
#
# [214 rows x 9 columns]

# %%
print(y_train)
# Out:
# 58      5.0
# 57     28.5
# 96     71.0
# 210    24.0
# 569    32.0
#        ...
# 93     26.0
# 135    23.0
# 338    45.0
# 549     8.0
# 131    20.0
# Name: Age, Length: 498, dtype: float64

# %%
print(y_test)
# Out:
# 641    24.0
# 496    54.0
# 262    52.0
# 311    18.0
# 551    27.0
#        ...
# 818    43.0
# 478    22.0
# 325    36.0
# 175    18.0
# 37     21.0
# Name: Age, Length: 214, dtype: float64
